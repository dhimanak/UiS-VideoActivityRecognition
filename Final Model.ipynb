# %%
import numpy as np
import cv2
import os
import math
data = list()
n = 5000
for i in range(n):
	data.append([i+1, (i+1)*10])
data = np.array(data)
print(data[:5, :])
print(data.shape)


cap = cv2.VideoCapture('Badminton.mp4')
frameRate = cap.get(5)
while(cap.isOpened()):
    frameId = cap.get(1) #current frame number
    ret, frame = cap.read()
    if (ret != True):
        break
    if (frameId % math.floor(frameRate) == 0):
        
        # storing the frames in a new folder named train_1
        
        filename ='badm/' + "_frame%d.jpg" %count
        count = count+1
        cv2.imwrite(filename, frame)
os.chdir(path = "/content/drive/MyDrive/Data2/test/HighJump/")
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir() if isfile(join('', f))]
HighJump =  onlyfiles[1:]


os.chdir(path="../LongJump/")
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir() if isfile(join('', f))]
longJump =  onlyfiles[1:]

HighJump,longJump

os.chdir(path="/content/drive/MyDrive/Data2/test/CricketBowling/")

from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir() if isfile(join('', f))]
bowling = onlyfiles
bowling




longJumpTest = longJump[int(len(longJump)*0.7):]
bowlingTest = bowling[int(len(bowling)*0.7):]
HighJumpTest  = HighJump[int(len(HighJump)*0.7):]
testNames = []
for each in longJumpTest:
    testNames.append(each)
for each in bowlingTest:
    testNames.append(each)
for each in HighJumpTest:
    testNames.append(each)
import pandas as pd
train = pd.DataFrame()
train['video_Names']=trainNames
# train['video_Names'][1].split('_')[1]

test = pd.DataFrame()
test['video_Names'] = testNames
train_video_tag = []

for i in range(train.shape[0]):
    train_video_tag.append(train['video_Names'][i].split('_')[1])
train['tag'] = train_video_tag
test_video_tag = []
for i in range(test.shape[0]):
    test_video_tag.append(test['video_Names'][i].split('_')[1])
test_video_tag

test['tag'] = test_video_tag
train


test = "/content/drive/MyDrive/Data2/test_featured.csv/"
# Out:
# [[ 1 10]
#  [ 2 20]
#  [ 3 30]
#  [ 4 40]
#  [ 5 50]]
# (5000, 2)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-2b4d169fe496> in <module>()
#      26         count = count+1
#      27         cv2.imwrite(filename, frame)
# ---> 28 os.chdir(path = "/content/drive/MyDrive/Data2/test/HighJump/")
#      29 from os import listdir
#      30 from os.path import isfile, join
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Data2/test/HighJump/'

# %% [markdown]
# # New section

# %% [markdown]
# #VideoClassification

# %%
import os
import numpy as np
import pandas as pd
import cv2 as cv2
import random as random
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import datasets, layers, models

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Reading Data

# %%
os.chdir("/content/drive/MyDrive/Data2")

# %%
# !ls
# Out:
# test  test_featured.csv  train	train_featured.csv

# %%
# os.chdir('Data')

# %%
def read_data(train_path = "/content/drive/MyDrive/Data2/train/HighJump/",test_path = "/content/drive/MyDrive/Data2/test/" ):
  train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
      rescale = 1./255,
      validation_split=0.2,
      shear_range = 0.2, # random application of shearing
      zoom_range = 0.2,
      horizontal_flip = True) # randomly flipping half of the images horizontally

  train_generator = train_datagen.flow_from_directory(
      train_path,
      target_size = (256, 256),
      shuffle = True,
      color_mode = "rgb")
  test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255)
  validation_generator = test_datagen.flow_from_directory(
      test_path,
      target_size = (256, 256),
      batch_size = 15,
      shuffle=True,
      color_mode = 'rgb')
  return (train_generator,validation_generator)

train_generator,validation_generator = read_data("data3/train/","data3/test/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-dd4e1d312746> in <module>()
#      20   return (train_generator,validation_generator)
#      21
# ---> 22 train_generator,validation_generator = read_data("data3/train/","data3/test/")
#
# <ipython-input-13-dd4e1d312746> in read_data(train_path, test_path)
#      10       train_path,
#      11       shuffle = True,
# ---> 12       color_mode = "rgb")
#      13   test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255)
#      14   validation_generator = test_datagen.flow_from_directory(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     956         follow_links=follow_links,
#     957         subset=subset,
# --> 958         interpolation=interpolation)
#     959
#     960   def flow_from_dataframe(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/preprocessing/image.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, dtype)
#     394         subset=subset,
#     395         interpolation=interpolation,
# --> 396         **kwargs)
#     397
#     398
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/directory_iterator.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, dtype)
#     113         if not classes:
#     114             classes = []
# --> 115             for subdir in sorted(os.listdir(directory)):
#     116                 if os.path.isdir(os.path.join(directory, subdir)):
#     117                     classes.append(subdir)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data3/train/'

# %% [markdown]
# ##**Modelling**

# %% [markdown]
# ###Part 1: Spacial Featuring
# ---

# %% [markdown]
# #### Modelling

# %%
model1 = models.Sequential()
model1.add(layers.Conv2D(32, (3,3), input_shape = (256, 256, 3), activation = 'relu'))
model1.add(layers.MaxPooling2D(pool_size = (2,2)))
model1.add(layers.Dropout(0.05))
model1.add(layers.Conv2D(64, (3,3), activation = 'relu'))
model1.add(layers.MaxPooling2D(pool_size = (2,2)))
model1.add(layers.Dropout(0.35))
model1.add(layers.Flatten())
model1.add(layers.Dense(200,activation = 'relu'))
model1.add(layers.Dense(3, activation = 'softmax'))
model1.compile(loss = tf.keras.losses.CategoricalCrossentropy(),optimizer= 'adam',
              metrics = ['accuracy'])

# %%
model1.load_weights("modelCNN.h5")

# %%
#model1.fit(train_generator,validation_data=validation_generator,epochs = 10,batch_size = 16)
model1.save_weights("modelCNN.h5")

# %%
model1.evaluate(validation_generator)
# Out:
# 106/106 [==============================] - 671s 6s/step - loss: 1.9906 - accuracy: 0.5855
# [1.9096027612686157, 0.597484290599823]

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 254, 254, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 127, 127, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 125, 125, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 62, 62, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 246016)            0
# _________________________________________________________________
# dense (Dense)                (None, 200)               49203400
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 603
# =================================================================
# Total params: 49,223,395
# Trainable params: 49,223,395
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ####Feature Extraction
# ---
# There two options to extract layers from
#
#
# 1.   Last Dense Layer
# 2.   Last Convoluted layer
# 3.   Last layer from InceptionResNetV2
#
# Convoluted layer is found to reach maximum of 50% accuracy on LSTM model in video prediction, while last Dense layer is found to have lower accuracy that is lesser than 50% on evaluation data with different number of units.Also, This may well change with change in number of nodes of dense layer and with change in data. InceptionRestNetV2 on imagenet trained wts. had much lesser accuracy of 20%. Other available models also did not perform any better.

# %% [markdown]
# #####Features: Dense layer

# %%
modelfeatured1 = models.Model(
    inputs=model1.input,
    outputs=model1.get_layer('1').output
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-755ccf41c629> in <module>()
#       1 modelfeatured1 = models.Model(
#       2     inputs=model1.input,
# ----> 3     outputs=model1.get_layer('1').output
#       4 )
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in get_layer(self, name, index)
#    2421         if layer.name == name:
#    2422           return layer
# -> 2423       raise ValueError('No such layer: ' + name + '.')
#    2424     raise ValueError('Provide either a layer name or layer index.')
#    2425
#
# ValueError: No such layer: 1.

# %% [markdown]
# #####Features: Convoluted layer

# %%
modelfeatured2 = models.Model(
    inputs=model1.input,
    outputs=model1.get_layer('flatten').output
)

# %%
base_model = tf.keras.applications.inception_v3.InceptionV3(
    weights='imagenet',
    include_top=True
)
# We'll extract features at the final pool layer.
modelfeatured3 = models.Model(
    inputs=base_model.input,
    outputs=base_model.get_layer('avg_pool').output
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96116736/96112376 [==============================] - 1s 0us/step

# %%
def read_data(train_path = "train/",test_path = "test/" ):
  train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
      rescale = 1./255,
      #validation_split=0.2,
      shear_range = 0.2, # random application of shearing
      zoom_range = 0.2,
      horizontal_flip = True) # randomly flipping half of the images horizontally

  train_generator = train_datagen.flow_from_directory(
      train_path,
      target_size = (256, 256),
      shuffle = False,
      color_mode = "rgb")
  test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255)
  validation_generator = test_datagen.flow_from_directory(
      test_path,
      target_size = (256, 256),
      batch_size = 15,
      shuffle=False,
      color_mode = 'rgb')
  return (train_generator,validation_generator)

train_generator2,validation_generator2 = read_data("data3/train/","data3/test/")
# Out:
# Found 3660 images belonging to 3 classes.
# Found 1590 images belonging to 3 classes.

# %%
'''modelfeatured as on your feature model from the above'''

#modelfeatured = modelfeatured1
#modelfeatured = modelfeatured2
#modelfeatured = modelfeatured3

train_featured = modelfeatured.predict(train_generator)
test_featured = modelfeatured.predict(validation_generator)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-53605654bff0> in <module>()
#       5 #modelfeatured = modelfeatured3
#       6
# ----> 7 train_featured = modelfeatured.predict(train_generator)
#       8 test_featured = modelfeatured.predict(validation_generator)
#
# NameError: name 'modelfeatured' is not defined

# %%
np.savetxt('data3/ftrainf.csv',train_featured, delimiter=',')
np.savetxt('data3/ftestf.csv',test_featured, delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-70242366b7ab> in <module>()
# ----> 1 np.savetxt('data3/ftrainf.csv',train_featured, delimiter=',')
#       2 np.savetxt('data3/ftestf.csv',test_featured, delimiter=',')
#
# NameError: name 'train_featured' is not defined

# %% [markdown]
# ### Part 2: Temporal Featuring

# %%
# !ls
# Out:
# data3  Data4  dataset  features  modelCNN.h5  modelFF.h5  modelLstm.h5

# %%
DATADIR="Data4/usethis/final/multiribzv5/"

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
      rescale = 1./255,
      shear_range = 0.2, # random application of shearing
      zoom_range = 0.2,
      validation_split=0.2,
      horizontal_flip = True) # randomly flipping half of the images horizontally

train_generator = train_datagen.flow_from_directory(
      DATADIR,
      target_size = (256, 256),
      shuffle = True,
      color_mode = "rgb")
# Out:
# Found 1079 images belonging to 4 classes.

# %%
model = models.Sequential()
model.add(layers.Conv2D(256, kernel_size=(1, 1),input_shape=(256,256, 3)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(layers.MaxPooling2D((3, 3)))

model.add(layers.Conv2D(128, (3, 3)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(3, 3)))

model.add(layers.Conv2D(64, (3, 3)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Conv2D(64, (1, 1)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Flatten())

model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.3))

model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.3))       
model.add(layers.Dense(4, activation='softmax'))

# %%
model.compile(optimizer="adam",loss=tf.keras.losses.CategoricalCrossentropy(),metrics=['accuracy'])
model.load_weights('modelFF.h5')
#callback = tf.keras.callbacks.EarlyStopping(patience=3)
#model.fit(train_generator,epochs=9,batch_size=6)
#model.save_weights("modelFF.h5")

# %%
model.evaluate_generator(train_generator)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# [1.3683077096939087, 0.40593141317367554]

# %%
train_datagen =  tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        'data3/train',
        target_size=(256, 256),
        color_mode="rgb",
        shuffle = False,
        class_mode='categorical',
        batch_size=1)

filenames = train_generator.filenames
nb_samples = len(filenames)

predict = model.predict_generator(train_generator)
frame = pd.DataFrame(predict, columns=[1,2,3,4])
feature_train_1 = pd.DataFrame(frame.idxmax(axis=1),columns=["cat"])
# Out:
# Found 3660 images belonging to 3 classes.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
test_datagen1 =  tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

test_generator1 = test_datagen1.flow_from_directory(
        'data3/test',
        target_size=(256, 256),
        color_mode="rgb",
        shuffle = False,
        class_mode='categorical',
        batch_size=1)

#filenames = test_generator1.filenames
#nb_samples = len(filenames)

#predict = model.predict_generator(test_generator1)
#frame = pd.DataFrame(predict, columns=[1,2,3,4])
#feature_test_1 = pd.DataFrame(frame.idxmax(axis=1),columns=["cat"])
# Out:
# Found 1590 images belonging to 3 classes.

# %%
#os.makedirs("features")

# %%
feature_test_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-df9b6e984738> in <module>()
# ----> 1 feature_test_1
#
# NameError: name 'feature_test_1' is not defined

# %%
#feature_test_1.to_csv('features/feature_test_1.csv', index=False)
#feature_train_1.to_csv('features/feature_train_1.csv', index=False)

# %%
feature_test_1 = pd.read_csv('features/feature_test_1.csv')
feature_train_1 = pd.read_csv('features/feature_train_1.csv')

# %%
feature_test_1[340:400]
# Out:
#      cat
# 340    3
# 341    3
# 342    3
# 343    3
# 344    3
# 345    3
# 346    3
# 347    3
# 348    3
# 349    3
# 350    3
# 351    3
# 352    3
# 353    3
# 354    3
# 355    3
# 356    3
# 357    3
# 358    3
# 359    3
# 360    3
# 361    3
# 362    3
# 363    3
# 364    3
# 365    3
# 366    3
# 367    3
# 368    3
# 369    3
# 370    3
# 371    3
# 372    3
# 373    3
# 374    3
# 375    3
# 376    3
# 377    3
# 378    3
# 379    3
# 380    3
# 381    3
# 382    3
# 383    3
# 384    3
# 385    3
# 386    3
# 387    3
# 388    3
# 389    3
# 390    3
# 391    3
# 392    3
# 393    3
# 394    3
# 395    3
# 396    3
# 397    3
# 398    3
# 399    3

# %% [markdown]
# ###Part 3: LSTM Modelling
#
# -----
# Here LSTM model is build on the sequenced dataframes from each video
# These dataframes have
#
#  ***extracted***
#
# 1.   *spacial features from the cnn model*
# 2.   *temporal features from cnn or other models*
#
# timesteps depend on the set frame rate

# %%
df = np.genfromtxt('data3/ftrainf.csv', delimiter=',')
scaler=MinMaxScaler()

scaled=scaler.fit_transform(df)
df=pd.DataFrame(scaled)

kmean4=KMeans(n_clusters=4)
kmean4.fit(df)
y_hat = kmean4.predict(df)
feature_train_2 = y_hat.reshape(y_hat.shape[0],1)

# %%
df = np.genfromtxt('data3/ftestf.csv', delimiter=',')
scaler=MinMaxScaler()

scaled=scaler.fit_transform(df)
df=pd.DataFrame(scaled)

kmean4=KMeans(n_clusters=4)
kmean4.fit(df)
y_hat = kmean4.predict(df)
feature_test_2 = y_hat.reshape(y_hat.shape[0],1)

# %%
#np.savetxt('features/feature_test_2.csv',feature_test_2, delimiter=',')
#np.savetxt('features/feature_train_2.csv',feature_train_2, delimiter=',')
feature_test_2 = np.genfromtxt('features/feature_test_2.csv', delimiter=',')
feature_train_2 = np.genfromtxt('features/feature_train_2.csv', delimiter=',')
feature_train_2 = feature_train_2.reshape(feature_train_2.shape[0],1)
feature_test_2 = feature_test_2.reshape(feature_test_2.shape[0],1)

# %%
train_featured = np.genfromtxt('data3/ftrainf.csv', delimiter=',')
test_featured = np.genfromtxt('data3/ftestf.csv', delimiter=',')
n_steps = 30  ##We set frame rate as 30
n_features = test_featured.shape[1]+2

# %%
test_featured = np.append(test_featured,feature_test_1,axis=1)
train_featured = np.append(train_featured,feature_train_1,axis=1)
test_featured = np.append(test_featured,feature_test_2,axis=1)
train_featured = np.append(train_featured,feature_train_2,axis=1)

# %% [markdown]
# ####Data Processing

# %%
train_featured.shape
# Out:
# (3660, 202)

# %%
temp = train_featured[:n_steps]
temp = temp.reshape(1,n_steps,temp.shape[1])
for i in range(n_steps,train_featured.shape[0],n_steps):
  temp = np.append(temp,train_featured[i:i+n_steps].reshape(1,n_steps,train_featured.shape[1]),axis = 0)
trainX = temp
temp = test_featured[:n_steps]
temp = temp.reshape(1,temp.shape[0],temp.shape[1])
for i in range(n_steps,test_featured.shape[0],n_steps):
  temp = np.append(temp,test_featured[i:i+n_steps].reshape(1,n_steps,test_featured.shape[1]),axis = 0)
testX = temp

# %%
trainX.shape
# Out:
# (122, 30, 202)

# %%
train_generator,validation_generator = read_data("data3/train/","data3/test/")
# Out:
# Found 3660 images belonging to 3 classes.
# Found 1590 images belonging to 3 classes.

# %%
y_train = []
for i in train_generator.filenames:
  if(i.split("/")[0]=="CricketBowling"):
    y_train.append(-100) 
  elif(i.split("/")[0]=="HighJump"):
    y_train.append(0)
  elif(i.split("/")[0]=="LongJump"):
    y_train.append(100) 

y_test = []
for i in validation_generator.filenames:
  if(i.split("/")[0]=="CricketBowling"):
    y_test.append(-100) 
  elif(i.split("/")[0]=="HighJump"):
    y_test.append(0)
  elif(i.split("/")[0]=="LongJump"):
    y_test.append(100) 

trainY=[]
for i in range(0,len(y_train),n_steps):
  trainY.append(y_train[i])
testY=[]
for i in range(0,len(y_test),n_steps):
  testY.append(y_test[i])


trainY = np.array(trainY)
testY = np.array(testY)

trainY=[]
for i in range(0,len(y_train),n_steps):
  trainY.append(y_train[i])
testY=[]
for i in range(0,len(y_test),n_steps):
  testY.append(y_test[i])



TRAINy = pd.DataFrame(trainY)
TRAINy.columns = ['label']
TRAINy['1']=0
TRAINy['2']=0
TRAINy['3']=0
for i in TRAINy.loc[TRAINy['label']==-100].index:
  TRAINy.loc[i,"1"]=1
for i in TRAINy.loc[TRAINy['label']==0].index:
  TRAINy.loc[i,"2"]=1
for i in TRAINy.loc[TRAINy['label']==100].index:
  TRAINy.loc[i,"3"]=1
final_trainY =np.array(TRAINy[['1','2','3']])

TESTy = pd.DataFrame(testY)
TESTy.columns = ['label']
TESTy['1']=0
TESTy['2']=0
TESTy['3']=0
for i in TESTy.loc[TESTy['label']==-100].index:
  TESTy.loc[i,"1"]=1
for i in TESTy.loc[TESTy['label']==0].index:
  TESTy.loc[i,"2"]=1
for i in TESTy.loc[TESTy['label']==100].index:
  TESTy.loc[i,"3"]=1
final_testY = np.array(TESTy[['1','2','3']])

# %% [markdown]
# #### Model Building

# %%
testX.shape
# Out:
# (53, 30, 202)

# %%
model2 = models.Sequential()
model2.add(layers.LSTM(500, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
model2.add(tf.keras.layers.BatchNormalization())
model2.add(layers.LSTM(500, activation='relu'))
model2.add(layers.Dense(3,activation="softmax"))

# %%
final_trainY.shape
# Out:
# (122, 3)

# %%
#optimizer = tf.keras.optimizers.Adam(lr=1e-4, decay=1e-5)
model2.compile(loss=tf.keras.losses.CategoricalCrossentropy(), optimizer='adam',
                    metrics=['accuracy','top_k_categorical_accuracy'])
#model2.load_weights("modelLstm.h5")
model2.fit(trainX,final_trainY,validation_data=(testX,final_testY),batch_size=8,epochs=500)
#model2.evaluate(testX,final_testY,batch_size = 8)
#model2.save_weights("modelLstm.h5")
# Out:
# Epoch 1/500
# 16/16 [==============================] - 11s 567ms/step - loss: 1.2627 - accuracy: 0.4439 - top_k_categorical_accuracy: 1.0000 - val_loss: 53.8757 - val_accuracy: 0.2642 - val_top_k_categorical_accuracy: 1.0000
# Epoch 2/500
# 16/16 [==============================] - 8s 510ms/step - loss: 1.0025 - accuracy: 0.4966 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.2552 - val_accuracy: 0.4717 - val_top_k_categorical_accuracy: 1.0000
# Epoch 3/500
# 16/16 [==============================] - 8s 514ms/step - loss: 0.9534 - accuracy: 0.5006 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.2671 - val_accuracy: 0.3019 - val_top_k_categorical_accuracy: 1.0000
# Epoch 4/500
# 16/16 [==============================] - 8s 512ms/step - loss: 0.8929 - accuracy: 0.6363 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.1425 - val_accuracy: 0.3962 - val_top_k_categorical_accuracy: 1.0000
# Epoch 5/500
# 16/16 [==============================] - 8s 488ms/step - loss: 0.8384 - accuracy: 0.5711 - top_k_categorical_accuracy: 1.0000 - val_loss: 2.2337 - val_accuracy: 0.4717 - val_top_k_categorical_accuracy: 1.0000
# Epoch 6/500
# 16/16 [==============================] - 8s 509ms/step - loss: 1.2415 - accuracy: 0.5296 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.2965 - val_accuracy: 0.2642 - val_top_k_categorical_accuracy: 1.0000
# Epoch 7/500
# 16/16 [==============================] - 8s 516ms/step - loss: 0.7960 - accuracy: 0.6879 - top_k_categorical_accuracy: 1.0000 - val_loss: 2.0145 - val_accuracy: 0.2453 - val_top_k_categorical_accuracy: 1.0000
# Epoch 8/500
# 16/16 [==============================] - 8s 512ms/step - loss: 0.9334 - accuracy: 0.5358 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.9018 - val_accuracy: 0.2453 - val_top_k_categorical_accuracy: 1.0000
# Epoch 9/500
# 16/16 [==============================] - 8s 509ms/step - loss: 0.7239 - accuracy: 0.7278 - top_k_categorical_accuracy: 1.0000 - val_loss: 1.6109 - val_accuracy: 0.3019 - val_top_k_categorical_accuracy: 1.0000
# Epoch 10/500
# 16/16 [==============================] - 8s 500ms/step - loss: 0.7334 - accuracy: 0.6950 - top_k_categorical_accuracy: 1.0000 - val_loss: 2.0781 - val_accuracy: 0.2453 - val_top_k_categorical_accuracy: 1.0000
# Epoch 11/500
# 16/16 [==============================] - 9s 540ms/step - loss: 0.7822 - accuracy: 0.6679 - top_k_categorical_accuracy: 1.0000 - val_loss: 2.0567 - val_accuracy: 0.4528 - val_top_k_categorical_accuracy: 1.0000
# Epoch 12/500
# 16/16 [==============================] - 9s 562ms/step - loss: 0.8201 - accuracy: 0.6199 - top_k_categorical_accuracy: 1.0000 - val_loss: 2.0879 - val_accuracy: 0.4340 - val_top_k_categorical_accuracy: 1.0000
# Epoch
- top_k_categorical_accuracy: 1.0000 - val_loss: 5.3852 - val_accuracy: 0.2642 - val_top_k_categorical_accuracy: 1.0000
# Epoch 487/500
# 16/16 [==============================] - 9s 534ms/step - loss: 0.1753 - accuracy: 0.9391 - top_k_categorical_accuracy: 1.0000 - val_loss: 6.0330 - val_accuracy: 0.3019 - val_top_k_categorical_accuracy: 1.0000
# Epoch 488/500
# 16/16 [==============================] - 9s 561ms/step - loss: 0.2918 - accuracy: 0.8825 - top_k_categorical_accuracy: 1.0000 - val_loss: 6.4316 - val_accuracy: 0.2830 - val_top_k_categorical_accuracy: 1.0000
# Epoch 489/500
# 16/16 [==============================] - 9s 554ms/step - loss: 0.1251 - accuracy: 0.9650 - top_k_categorical_accuracy: 1.0000 - val_loss: 5.9514 - val_accuracy: 0.2453 - val_top_k_categorical_accuracy: 1.0000
# Epoch 490/500
# 16/16 [==============================] - 9s 543ms/step - loss: 0.0837 - accuracy: 0.9784 - top_k_categorical_accuracy: 1.0000 - val_loss: 4.9683 - val_accuracy: 0.3208 - val_top_k_categorical_accuracy: 1.0000
# Epoch 491/500
# 16/16 [==============================] - 9s 559ms/step - loss: 0.1281 - accuracy: 0.9446 - top_k_categorical_accuracy: 1.0000 - val_loss: 4.6999 - val_accuracy: 0.3774 - val_top_k_categorical_accuracy: 1.0000
# Epoch 492/500
# 16/16 [==============================] - 9s 569ms/step - loss: 0.0860 - accuracy: 0.9700 - top_k_categorical_accuracy: 1.0000 - val_loss: 4.7955 - val_accuracy: 0.3962 - val_top_k_categorical_accuracy: 1.0000
# Epoch 493/500
# 16/16 [==============================] - 9s 550ms/step - loss: 0.0674 - accuracy: 0.9881 - top_k_categorical_accuracy: 1.0000 - val_loss: 4.0411 - val_accuracy: 0.3396 - val_top_k_categorical_accuracy: 1.0000
# Epoch 494/500
# 16/16 [==============================] - 9s 545ms/step - loss: 0.0769 - accuracy: 0.9528 - top_k_categorical_accuracy: 1.0000 - val_loss: 5.1665 - val_accuracy: 0.3585 - val_top_k_categorical_accuracy: 1.0000
# Epoch 495/500
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0497 - accuracy: 0.9885 - top_k_categorical_accuracy: 1.0000 - val_loss: 5.4846 - val_accuracy: 0.3019 - val_top_k_categorical_accuracy: 1.0000
# Epoch 496/500
# 16/16 [==============================] - 9s 534ms/step - loss: 0.0416 - accuracy: 0.9980 - top_k_categorical_accuracy: 1.0000 - val_loss: 5.2108 - val_accuracy: 0.3396 - val_top_k_categorical_accuracy: 1.0000
# Epoch 497/500
# 16/16 [==============================] - 9s 584ms/step - loss: 0.0599 - accuracy: 0.9881 - top_k_categorical_accuracy: 1.0000 - val_loss: 6.0799 - val_accuracy: 0.3208 - val_top_k_categorical_accuracy: 1.0000
# Epoch 498/500
# 16/16 [==============================] - 9s 545ms/step - loss: 0.0398 - accuracy: 0.9820 - top_k_categorical_accuracy: 1.0000 - val_loss: 6.3736 - val_accuracy: 0.3019 - val_top_k_categorical_accuracy: 1.0000
# Epoch 499/500
# 16/16 [==============================] - 9s 555ms/step - loss: 0.0112 - accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 6.3565 - val_accuracy: 0.3019 - val_top_k_categorical_accuracy: 1.0000
# Epoch 500/500
# 16/16 [==============================] - 9s 531ms/step - loss: 0.0123 - accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - val_loss: 5.6687 - val_accuracy: 0.3208 - val_top_k_categorical_accuracy: 1.0000

# %%
model2.evaluate(testX)
# Out:
# 2/2 [==============================] - 1s 105ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - top_k_categorical_accuracy: 0.0000e+00
# [0.0, 0.0, 0.0]

# %%
model2.save_weights("modelLstm.h5")

# %% [markdown]
# ##Predictions

# %%
predicts = model2.predict(trainX)
frame = pd.DataFrame(predicts, columns=[1,2,3])
classification = pd.DataFrame(frame.idxmax(axis=1),columns=["cat"])

# %%
classification
# Out:
#      cat
# 0      2
# 1      3
# 2      2
# 3      2
# 4      3
# ..   ...
# 117    3
# 118    3
# 119    3
# 120    3
# 121    3
#
# [122 rows x 1 columns]
